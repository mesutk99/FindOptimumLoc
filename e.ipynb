# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("eğitim_ibb_1.csv", sep=";",encoding='iso-8859-9')
data.head(100)
# Out:
#     ilce_adi      mahalle_adi  lise_alti_oranii  lise_dengi_orani  universite  \
# 0   BAĞCILAR           15.Tem                75                16           9
# 1   BAĞCILAR         100. YIL                78                15           7
# 2   BAĞCILAR           BAĞLAR                56                25          19
# 3   BAĞCILAR         BARBAROS                72                18          10
# 4   BAĞCILAR            ÇINAR                70                19          11
# ..       ...              ...               ...               ...         ...
# 95   ESENLER  KAZIM KARABEKİR                74                17           9
# 96   ESENLER            KEMER                73                17          10
# 97   ESENLER         MENDERES                71                19          10
# 98   ESENLER      MİMAR SİNAN                65                21          14
# 99   ESENLER      NAMIK KEMAL                73                17          10
#
#         Rank
# 0   0.157895
# ...

# %%
data=data[["ilce_adi","Rank"]]
data.head()
# Out:
#    ilce_adi      Rank
# 0  BAĞCILAR  0.157895
# 1  BAĞCILAR  0.122807
# 2  BAĞCILAR  0.333333
# 3  BAĞCILAR  0.175439
# 4  BAĞCILAR  0.192982

# %%
data.groupby('ilce_adi').agg(['mean'])
# Out:
#                   Rank
#                   mean
# ilce_adi
# BAHÇELİEVLER  0.322169
# BAYRAMPAŞA    0.259968
# BAĞCILAR      0.188198
# BEYOĞLU       0.414425
# ESENLER       0.169956
